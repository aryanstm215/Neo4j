# %%
# !pip install pdf2image

# %%
# !pip install pdfminer.six

# %%
# !pip install unstructured[pdf]

# %%
# !pip install unstructured

# %%
# %pip install langchain_community
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.2/2.2 MB 25.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 974.6/974.6 kB 64.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 321.8/321.8 kB 40.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.1/127.1 kB 18.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 145.0/145.0 kB 10.9 MB/s eta 0:00:00
# ...

# %%
# !sudo apt-get update
# Out:
# Get:1 http://security.ubuntu.com/ubuntu jammy-security InRelease [129 kB]
# Get:2 https://cloud.r-project.org/bin/linux/ubuntu jammy-cran40/ InRelease [3,626 B]
# Get:3 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  InRelease [1,581 B]
# Hit:4 http://archive.ubuntu.com/ubuntu jammy InRelease
# Get:5 http://archive.ubuntu.com/ubuntu jammy-updates InRelease [128 kB]
# Get:6 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  Packages [929 kB]
# Get:7 http://security.ubuntu.com/ubuntu jammy-security/universe amd64 Packages [1,093 kB]
# Hit:8 https://ppa.launchpadcontent.net/c2d4u.team/c2d4u4.0+/ubuntu jammy InRelease
# Get:9 http://security.ubuntu.com/ubuntu jammy-security/restricted amd64 Packages [2,474 kB]
# Hit:10 https://ppa.launchpadcontent.net/deadsnakes/ppa/ubuntu jammy InRelease
# Get:11 http://security.ubuntu.com/ubuntu jammy-security/main amd64 Packages [1,922 kB]
# ...

# %%
# !sudo apt-get install poppler-utils
# Out:
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# The following NEW packages will be installed:
#   poppler-utils
# 0 upgraded, 1 newly installed, 0 to remove and 45 not upgraded.
# Need to get 186 kB of archives.
# After this operation, 696 kB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 poppler-utils amd64 22.02.0-2ubuntu0.4 [186 kB]
# Fetched 186 kB in 0s (1,232 kB/s)
# debconf: unable to initialize frontend: Dialog
# debconf: (No usable dialog-like program is installed, so the dialog based frontend cannot be used. at /usr/share/perl5/Debconf/FrontEnd/Dialog.pm line 78, <> line 1.)
# debconf: falling back to frontend: Readline
# debconf: unable to initialize frontend: Readline
# debconf: (This frontend requires a controlling tty.)
# debconf: falling back to frontend: Teletype
# dpkg-preconfigure: unable to re-open stdin:
# ...

# %%
# !sudo apt-get install libleptonica-dev tesseract-ocr libtesseract-dev python3-pil tesseract-ocr-eng tesseract-ocr-script-latn
# Out:
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# The following additional packages will be installed:
#   libarchive-dev libimagequant0 libraqm0 mailcap mime-support python3-olefile
#   tesseract-ocr-osd
# Suggested packages:
#   python-pil-doc
# The following NEW packages will be installed:
#   libarchive-dev libimagequant0 libleptonica-dev libraqm0 libtesseract-dev
#   mailcap mime-support python3-olefile python3-pil tesseract-ocr
#   tesseract-ocr-eng tesseract-ocr-osd tesseract-ocr-script-latn
# 0 upgraded, 13 newly installed, 0 to remove and 45 not upgraded.
# Need to get 40.0 MB of archives.
# After this operation, 123 MB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libarchive-dev amd64 3.6.0-1ubuntu1.1 [582 kB]
# Get:2 http://archive.ubuntu.com/ubuntu jammy/main amd64 libimagequant0 amd64 2.17.0-1 [34.6 kB]
# ...

# %%
# !pip install unstructured-pytesseract
# !pip install tesseract-ocr
# Out:
# ...
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for tesseract-ocr: filename=tesseract_ocr-0.0.1-cp310-cp310-linux_x86_64.whl size=169755 sha256=3bc88a383aab58d96bb45416c2131af2d011706869c4a06365ab552f860baead
#   Stored in directory: /root/.cache/pip/wheels/bb/fd/f3/5c231ecbbb80a1fe33204ff3021d99b54ef6daf6f8099311b8
# Successfully built tesseract-ocr
# ...

# %%
# !pip install "unstructured[pptx]"
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 471.6/471.6 kB 8.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 159.9/159.9 kB 23.9 MB/s eta 0:00:00
# ...

# %%
# !pip install langchain_astradb
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 139.8/139.8 kB 5.5 MB/s eta 0:00:00
# ...
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 45.1/45.1 kB 6.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 18.9/18.9 MB 29.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.5/57.5 kB 8.2 MB/s eta 0:00:00
# ...
#   Created wheel for bson: filename=bson-0.5.10-py3-none-any.whl size=11976 sha256=5ca1b7d0f9cf1469580946fb7f4cf9652efa657618b8955d7aa466fad3bde045
#   Stored in directory: /root/.cache/pip/wheels/36/49/3b/8b33954dfae7a176009c4d721a45af56c8a9c1cdc3ee947945
# Successfully built bson
# ...

# %%
# !pip install langchain langchain-openai datasets pypdf
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 547.8/547.8 kB 14.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 327.4/327.4 kB 16.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 30.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 40.8/40.8 MB 18.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 116.3/116.3 kB 13.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 64.9/64.9 kB 8.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 194.1/194.1 kB 22.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 134.8/134.8 kB 8.2 MB/s eta 0:00:00
# ...
#   Attempting uninstall: requests
#     Found existing installation: requests 2.31.0
#     Uninstalling requests-2.31.0:
#       Successfully uninstalled requests-2.31.0
#   Attempting uninstall: pyarrow
#     Found existing installation: pyarrow 14.0.2
#     Uninstalling pyarrow-14.0.2:
# ...

# %%
from langchain_text_splitters import RecursiveCharacterTextSplitter

# %%
from langchain_community.document_loaders import DirectoryLoader

# %%
loader = DirectoryLoader('/content/docs')

# %%
splitter = RecursiveCharacterTextSplitter(chunk_size=512, chunk_overlap=64)

# %%
docs = loader.load_and_split(text_splitter=splitter)
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Unzipping taggers/averaged_perceptron_tagger.zip.

# %%
docs
# Out:
# [Document(page_content='National Institute of Technology , Agartala\n\nName -  Aryan \n\nMTech in “Artificial Intelligence”\n\nEnrollment no – 22PCS006.\n\nDepartment – Computer Science & Engineering.\n\nTopic - A deep learning approach for early Diabetic Retinopathy diagnosis: A novel lesion detection approach using SRGAN and Mask R-CNN.\n\nGuide – Dr.Suman Deb\n\n1\n\nIntroduction\n\nUnder the medical imaging section , Diabetic retinopathy poses a significant problem.', metadata={'source': '/content/docs/Aryan_final_year_ppt.pptx'}),
# ...

# %%
len(docs)
# Out:
# 201

# %%
from langchain_astradb import AstraDBVectorStore
from langchain.indexes import VectorstoreIndexCreator

# %%
ASTRA_DB_API_ENDPOINT="https://03c97d83-4326-4f6e-8dc3-2f9d77ce8743-us-east-2.apps.astra.datastax.com"
ASTRA_DB_APPLICATION_TOKEN="AstraCS:oGZOgdRaBzICZgjMxmQQdfdE:6ae47014278c16acb32810117b9f8d0b1b31fc63219a1ac798e7341263362b6e"
ASTRA_DB_KEYSPACE="default_keyspace"

# %%
## HERE I NEED TO DO THE ENBEDDINGDS AS WELL !

# %%
## HERE , I AM USING THE HUGGING FACE MODEL FOR EMBEDDINGTS !

# %%
# !pip install sentence-transformers
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 227.1/227.1 kB 5.0 MB/s eta 0:00:00
# ...

# %%
from langchain.embeddings import HuggingFaceEmbeddings

# %%
embedding_model_name = "sentence-transformers/all-mpnet-base-v2"
#model_kwargs = {"device": "cuda"}
embeddings = HuggingFaceEmbeddings(
  model_name=embedding_model_name,
  #model_kwargs=model_kwargs
)
# Out:
# /usr/local/lib/python3.10/dist-packages/langchain_core/_api/deprecation.py:139: LangChainDeprecationWarning: The class `HuggingFaceEmbeddings` was deprecated in LangChain 0.2.2 and will be removed in 0.3.0. An updated version of the class exists in the langchain-huggingface package and should be used instead. To use it run `pip install -U langchain-huggingface` and import as `from langchain_huggingface import HuggingFaceEmbeddings`.
#   warn_deprecated(
# /usr/local/lib/python3.10/dist-packages/sentence_transformers/cross_encoder/CrossEncoder.py:11: TqdmExperimentalWarning: Using `tqdm.autonotebook.tqdm` in notebook mode. Use `tqdm.tqdm` instead to force console mode (e.g. in jupyter console)
#   from tqdm.autonotebook import tqdm, trange
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_token.py:89: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# ...

# %%
vstore = AstraDBVectorStore(
    embedding=embeddings,
    collection_name="multidoc_vector",
    api_endpoint=ASTRA_DB_API_ENDPOINT,
    token=ASTRA_DB_APPLICATION_TOKEN,
    namespace=ASTRA_DB_KEYSPACE,
)

# %%
inserted_ids = vstore.add_documents(docs)

# %%
print(f"\nInserted {len(inserted_ids)} documents.")
# Out:
# Inserted 201 documents.

# %%
retriever = vstore.as_retriever(search_kwargs={"k": 3})

# %%
retriever
# Out:
# VectorStoreRetriever(tags=['AstraDBVectorStore', 'HuggingFaceEmbeddings'], vectorstore=<langchain_astradb.vectorstores.AstraDBVectorStore object at 0x7cacddaf29e0>, search_kwargs={'k': 3})

# %%
from langchain.chains import LLMChain
from langchain.llms import HuggingFaceHub
from langchain.prompts import PromptTemplate

# %%
# !pip install python-dotenv

# %%
import os
import time
from dotenv import load_dotenv

load_dotenv()
# Out:
# True

# %%
llm=HuggingFaceHub(repo_id='mistralai/Mistral-7B-Instruct-v0.2', model_kwargs={'temperature': 0.7, 'max_new_tokens': 250})

# %%
llm
# Out:
# HuggingFaceHub(client=<InferenceClient(model='mistralai/Mistral-7B-Instruct-v0.2', timeout=None)>, repo_id='mistralai/Mistral-7B-Instruct-v0.2', task='text-generation', model_kwargs={'temperature': 0.7, 'max_new_tokens': 250})

# %%
from transformers import pipeline, AutoModelForSeq2SeqLM, AutoTokenizer

# %%
prompt_template = """

Your responses should be concise and strictly related to the provided context.

ROADMAP CONTEXT:
{context}

QUESTION: {question}

YOUR ANSWER:"""

# %%
prompt_template = PromptTemplate.from_template(prompt_template)

# %%
vstore

# %%
from langchain_core.output_parsers import StrOutputParser

# %%
from langchain_core.runnables import RunnableLambda
def inspect(state):
    """Print the state passed between Runnables in a langchain and pass it on"""
    print(state)
    return state

# %%
from langchain_core.runnables import RunnablePassthrough

# %%
chain = (
    {"context": retriever, "question": RunnablePassthrough()}
    | prompt_template
    | llm
    | StrOutputParser()
)

# %%
chain.invoke("what is yolo ?")
# Out:
# "\n\nYour responses should be concise and strictly related to the provided context.\n\nROADMAP CONTEXT:\n[Document(page_content='[23] Jocher Glenn. YOLOv5 release v6.1. https://github.com/\\n\\nultralytics/yolov5/releases/tag/v6.1, 2022. 2, 7, 10', metadata={'source': '/content/docs/YOLO.pdf'}), Document(page_content='[23] Jocher Glenn. YOLOv5 release v6.1. https://github.com/\\n\\nultralytics/yolov5/releases/tag/v6.1, 2022. 2, 7, 10', metadata={'source': '/content/docs/YOLO.pdf'}), Document(page_content='[23] Jocher Glenn. YOLOv5 release v6.1. https://github.com/\\n\\nultralytics/yolov5/releases/tag/v6.1, 2022. 2, 7, 10', metadata={'source': '/content/docs/YOLO_Research.pdf'})]\n\nQUESTION: what is yolo ?\n\nYOUR ANSWER:\nYOLO (You Only Look Once) is an object detection system developed by Alexey AB Graham, Joseph Redmon, Ross Girshick, and Ali Farhadi, released under the YOLOv5 project led by Glenn Jocher. It is known for its real-time object detection capabilities. (Sources: [23] 
# ...

# %%
chain.invoke("who is pm of itlay ?")
# Out:
# "\n\nYour responses should be concise and strictly related to the provided context.\n\nROADMAP CONTEXT:\n[Document(page_content='7', metadata={'source': '/content/docs/YOLO.pdf'}), Document(page_content='7', metadata={'source': '/content/docs/YOLO_Research.pdf'}), Document(page_content='7', metadata={'source': '/content/docs/YOLO.pdf'})]\n\nQUESTION: who is pm of itlay ?\n\nYOUR ANSWER: I cannot determine the current prime minister of Italy from the given context. The context only mentions the YOLO documentation and research papers."

# %%
chain.invoke("can you tell me the pm of france")
# Out:
# "\n\nYour responses should be concise and strictly related to the provided context.\n\nROADMAP CONTEXT:\n[Document(page_content='7', metadata={'source': '/content/docs/YOLO.pdf'}), Document(page_content='7', metadata={'source': '/content/docs/YOLO_Research.pdf'}), Document(page_content='7', metadata={'source': '/content/docs/YOLO.pdf'})]\n\nQUESTION: can you tell me the pm of france\n\nYOUR ANSWER: The provided context does not contain information about the Prime Minister of France."

# %%
## implememtations from streamlit UI

# %%
chain.invoke("who is the pm of india?")
# Out:
# "\n\nYour responses should be concise and strictly related to the provided context.\n\nROADMAP CONTEXT:\n[Document(page_content='9\\n\\nArchitecture of Mask-RCNN model.\\n\\nRegion Proposal Network (RPN): Mask-RCNN begins with an RPN, which is responsible for generating region proposals or candidate bounding boxes in an image. It proposes potential regions that may contain objects of interest.', metadata={'source': '/content/docs/Aryan_final_year_ppt.pptx'}), Document(page_content='9\\n\\nArchitecture of Mask-RCNN model.\\n\\nRegion Proposal Network (RPN): Mask-RCNN begins with an RPN, which is responsible for generating region proposals or candidate bounding boxes in an image. It proposes potential regions that may contain objects of interest.', metadata={'source': '/content/docs/Aryan_final_year_ppt.pptx'}), Document(page_content='[56] Kemal Oksuz, Baris Can Cam, Emre Akbas, and Sinan Kalkan. A ranking-based, balanced loss function unifying classiﬁcation and localisation in object 
# ...
